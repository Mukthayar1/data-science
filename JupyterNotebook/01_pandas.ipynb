# %%
# !pip3 install openpyxl --quiet

# %%
# How to write file
import pandas as pd
import seaborn as sns

titanicData = sns.load_dataset("titanic") #pandas framwork
titanicData.to_excel("./titanicDat.xlsx")
titanicData.to_csv("./titanicDat.csv")

# %%
# How to write file
import pandas as pd
import seaborn as sns

df = pd.read_csv("./titanicDat.csv")
df_2 = pd.read_excel("./titanicDat.xlsx")

# %%
# pandas tips
df.info()

# %%
# top rows
df.head()

df.head(9)

# %%
df.tail()

df.tail(10)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 881         881         0       3    male  33.0      0      0   7.8958
# 882         882         0       3  female  22.0      0      0  10.5167
# 883         883         0       2    male  28.0      0      0  10.5000
# 884         884         0       3    male  25.0      0      0   7.0500
# 885         885         0       3  female  39.0      0      5  29.1250
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 881        S   Third    man        True  NaN  Southampton    no   True
# ...
